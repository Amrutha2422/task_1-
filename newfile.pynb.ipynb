# %%
a = int(input("Enter a Number :"))
b = int(input("Enter a Number :"))
c = int(input("Enter a Number :"))

if a>=b and a>=c:
    print ("a is biggest")
elif b>=a and b>=c:
    print ("B is biggest")
else :
    print ("C is biggest")
# Out:
# The kernel failed to start as 'eq' could not be imported from 'consider renaming 'c:\\Users\\amrut\\python\\operator.py' since it has the same name as the standard library module named 'operator' and prevents importing that standard library module'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %%
a=1
x=int(input("Enter no.of.rows :"))
y=int(input("Enter no.of.colums :"))
Symbol=input("Give any Symbol:(!/@/#/$/%/^/&) :")
while a<=x:
    b=1
    while b<=y:
        print(Symbol,end='')
        b+=1
    print()
    a+=1
# Out:
# The kernel failed to start as 'eq' could not be imported from 'consider renaming 'c:\\Users\\amrut\\python\\operator.py' since it has the same name as the standard library module named 'operator' and prevents importing that standard library module'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %%
a = 1
x = int(input("value:"))
y = int(input("value:"))
while a<=x: # row
    b = 1
    while b<=y: # columns
        print(b, end='')
        b += 1
    print() # cut next line
    a += 1
print("loop over")

# %%
for x in range(100,0,10):
    print(x,end='')
# Out:
# The kernel failed to start as the Python Environment 'Python 3.14.7' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
